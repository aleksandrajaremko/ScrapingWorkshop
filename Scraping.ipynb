# %% [markdown]
# Install the required packages

# %%
## If you are using pip to manage your environment
# %pip install altair plotnine BeautifulSoup4

## or if you are using conda to manage your environment
# %conda install altair plotnine BeautifulSoup4

# %%
import numpy as np
import pandas as pd

import requests                     # for making HTTP requests
from bs4 import BeautifulSoup       # for parsing HTML
import altair as alt                # for plotting
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap   # for plotting
import time

# %% [markdown]
# <a href="https://colab.research.google.com/github/fm-ds/ScrapingWorkshop/blob/main/Scraping.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Web Scraping
#
# This notebook introduces web scraping with the `requests` and `BeautifulSoup` modules using the scraping of a British retailer, M&S, as an example.
# First, scraping is demonstrated on some very simple HTML, then we will move to the real website.
#
# <br>
# <br>
#
# # Part 1. A Basic Example
# ## Searching HTML with `BeautifulSoup`
#
# BeautifulSoup is a Python library for parsing HTML documents. We can use it to extract data from HTML fetched from the web but first we'll try it out with a simple HTML example.

# %%
sample_html = """
<html>
<body>
    <h1> BeautifulSoup </h1>
    <p> BeautifulSoup is a Python library for parsing HTML documents. We can use it to extract data from HTML we fetch
        from the web.
        Here, we're just using it to parse some simple sample HTML.
    </p>
    <h2 class="important"> Searching the tree </h2>
    <p id="searching_description" style="color: red"> BeautifulSoup allows us to search the HTML tree in lots of different ways: by tag, by
        id, by CSS class, and so on. </p>
    <ol>
        <li role="example_1"> By tag: we could search for every li </li>
        <li role="example_2"> By id: we could search for the p tag with id="searching_description" </li>
        <li role="example_3" class="important"> By class: we could search for every tag with a given class </li>
        <li> and so on... </li>
    </ol>
    <div>
        <p>Div tags are used to group block-elements and structure the web page.</p>
    </div>
</body>
</html>
"""

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h4>HTML cheatsheet: Tags & Attributes</h4>
#
# An HTML element is a part of an HTML document that is made up of a start tag, some content, and then a closing tag: `<div>Some text about anything</div>`. These elements can also include attributes, which go in the start tag: `<div id="unique_abc">Some text</div>`.
#
# <br>
#
# **Tags** are the building blocks of HTML. They are used to define the structure and content of a web page. In the **`sample_html`**, **html**, **body**, **h1**, **p**, **h2**, **ol**, **li**, and **div** are examples of tags. Tags are open
# - `<html>`: The root element that defines the whole HTML document.
# - `<body>`: Contains the content of an HTML document.
# - `<h1>`, `<h2>`: Heading tags used to define headings. `<h1>` represents the main heading, while `<h2>` represents a subheading (heading tags go all the way down to <b>h6</b>, which is the smallest heading).
# - `<p>`: Defines a paragraph.
# - `<ol>`: Defines an ordered list.
# - `<li>`: Defines a list item within a list.
# - `<div>`: A block-level element used as a container to group and style sections of HTML documents with CSS or manipulate them with JavaScript.
#
# <br>
#
# **Attributes** provide additional information about an element's properties. They are always specified in the start tag of an element and usually come in name/value pairs like name="value". Common tags include:
# - `class`: An attribute used to specify a class name for an element. It is used by CSS and JavaScript to perform certain tasks for elements with the specified class name.
# - `id`: An attribute used to specify a unique id for an element. It is used to identify a single element in the document. In the sample, `id="searching_description"` is used to uniquely identify a paragraph.
# - `style`: Defines the inline CSS style for an element. For example, `style="color: red"` changes the text colour of the element to red.
# </div>

# %% [markdown]
# <br>
# <br>
#
# At present the `sample_html` is just a string. In order to search through it, we'll create a **Soup** object with beautifulSoup - a searchable object representation.

# %%
soup = BeautifulSoup(sample_html, 'html.parser')    # Parsing the HTML using BeautifulSoup and the built-in HTML parser 
print(soup.prettify())      # Print the HTML in a nicely formatted way (with indentation)
# Out:
# <html>
#  <body>
#   <h1>
#    BeautifulSoup
#   </h1>
#   <p>
#    BeautifulSoup is a Python library for parsing HTML documents. We can use it to extract data from HTML we fetch
#         from the web.
#         Here, we're just using it to parse some simple sample HTML.
#   </p>
#   <h2 class="important">
#    Searching the tree
#   </h2>
#   <p id="searching_description" style="color: red">
#    BeautifulSoup allows us to search the HTML tree in lots of different ways: by tag, by
#         id, by CSS class, and so on.
#   </p>
#   <ol>
#    <li role="example_1">
#     By tag: we could search for every li
#    </li>
#    <li role="example_2">
#     By id: we could search for the p tag with id="searching_description"
#    </li>
#    <li class="important" role="example_3">
#     By class: we could search for every tag with a given class
#    </li>
#    <li>
#     and so on...
#    </li>
#   </ol>
#   <div>
#    <p>
#     Div tags are used to group block-elements and structure the web page.
#    </p>
#   </div>
#  </body>
# </html>

# %% [markdown]
# <br>
#
# We can now search the `soup` object to extract useful information. Let's try searching by tag, attribute, and by both.
#
# Useful BeautifulSoup methods include:
# - `find()`: Searches for the first tag that matches a given name or filter, returning a single result.
# - `find_all()`: Searches for all tags that match a given name or filter, returning a list of results.
# - `get_text()`: Extracts all text from a tag and its children, returning a single string (`.text` also achieves this).
# - `get()`: Retrieves the value of a tag attribute, such as "href" in an `<a>` tag or "src" in an `<img>` tag.
#
# <br>
#
# **First, by tag:** Here's an example of using .find() to find the first `<p>` tag:

# %%
print(soup.find('p').get_text())
# Out:
#  BeautifulSoup is a Python library for parsing HTML documents. We can use it to extract data from HTML we fetch
#         from the web.
#         Here, we're just using it to parse some simple sample HTML.

# %%
# Finding the first occurrence of the <p> tag
first_p_tag = soup.find('p')
print(first_p_tag.get_text())
# Out:
#  BeautifulSoup is a Python library for parsing HTML documents. We can use it to extract data from HTML we fetch
#         from the web.
#         Here, we're just using it to parse some simple sample HTML.

# %% [markdown]
# What if we want to find the text of every list (`<li>`) element on the page? We can use `find_all()`

# %%
for element in soup.find_all('li'):
    print(element.get_text())
# Out:
#  By tag: we could search for every li
#  By id: we could search for the p tag with id="searching_description"
#  By class: we could search for every tag with a given class
#  and so on...

# %%
list_elements = soup.find_all('li') # Finding all the list elements in the HTML
for element in list_elements:
    print(element.text) # Printing the text of each list element
# Out:
#  By tag: we could search for every li
#  By id: we could search for the p tag with id="searching_description"
#  By class: we could search for every tag with a given class
#  and so on...

# %% [markdown]
# **Next, by id** let's find what the paragraph (`<p>`) with the `id` `searching_description` says and let's also take a look at its style.

# %%
soup.find('p', {'id': 'searching_description'}).get('style')
# Out:
# 'color: red'

# %%
# instead of using find_all, we can use `find()` to find the first element that matches the search criteria
description_element = soup.find('p', {'id': 'searching_description'}) # Finding the paragraph with id="searching_description"
description_element

print('text:', description_element.text) # Printing the text of the paragraph with id="searching_description"
print('style:', description_element.get('style')) # Printing the value of the style attribute of the paragraph with id="searching_description"
# Out:
# text:  BeautifulSoup allows us to search the HTML tree in lots of different ways: by tag, by
#         id, by CSS class, and so on.
# style: color: red

# %% [markdown]
# **by class:** let's find all elements with the `class` `important`

# %%
soup.find_all(class_='important')
# Out:
# [<h2 class="important"> Searching the tree </h2>,
#  <li class="important" role="example_3"> By class: we could search for every tag with a given class </li>]

# %%
important_elements = soup.find_all(class_='important') # Finding all the elements with class="important"
print(f"There are {len(important_elements)} elements with class='important'")
for element in important_elements:
    print(element) # Printing each element with class="important"
# Out:
# There are 2 elements with class='important'
# <h2 class="important"> Searching the tree </h2>
# <li class="important" role="example_3"> By class: we could search for every tag with a given class </li>

# %% [markdown]
# **finally**, we can search in any way we want by supplying a function of our own
#
# let's write a simple function that identifies whether an element's `role` attribute that starts with `example-`

# %%
def important_role(role_attribute):
    return role_attribute != None and 'example_' in role_attribute

# Find the first <ol> element
ol_element = soup.find('ol')
ol_element.find_all('li', role=important_role) # Finding all the list elements with a role attribute that contains 'example-'
# Out:
# [<li role="example_1"> By tag: we could search for every li </li>,
#  <li role="example_2"> By id: we could search for the p tag with id="searching_description" </li>,
#  <li class="important" role="example_3"> By class: we could search for every tag with a given class </li>]

# %% [markdown]
# <br>
# <br>
#
# ## Getting HTML from the web with `Requests`
#
# <div style="display: flex; align-items: flex-start;">
#     <div style="flex: 0 2 auto;">
#         <img src="https://raw.githubusercontent.com/FM-ds/ScrapingWorkshop/main/notebook_images/sample_html_safari.png" width="400px">
#     </div>
#     <div style="flex: 1 1 auto; margin-top: 10px; margin-right: 150px">
#         <p>We just extracted information from HTML which was defined locally in a string <code>sample_html</code>. Usually, we care about HTML found on the internet. As a simple example, the page defined in <code>sample_html</code> is available at <a href="http://www.fmcevoy.io/ScrapingWorkshop/sample_html">http://www.fmcevoy.io/ScrapingWorkshop/sample_html</a></p>
#         <p>To download HTML (and any other resources) from the internet, we can use the <code>requests</code> module.</p>
#     </div>
# </div>

# %%
req = requests.get('http://www.fmcevoy.io/ScrapingWorkshop/sample_html') # Making a request for the sample HTML hosted on the web
req.text # looking at the text of the response
# Out:
# '<html>\n<body>\n    <h1> BeautifulSoup </h1>\n    <p> BeautifulSoup is a Python library for parsing HTML documents. We can use it to extract data from HTML we fetch\n        from the web.\n        Here, we\'re just using it to parse some simple sample HTML. </p>\n\n    <h2 class="important"> Searching the tree </h2>\n    <p id="searching_description" style="color: red"> BeautifulSoup allows us to search the HTML tree in lots of different ways: by tag, by\n        id, by CSS class, and so on. </p>\n    <ol>\n        <li role="example_1"> By tag: we could search for every li </li>\n        <li role="example_2"> By id: we could search for the p tag with id="searching_description" </li>\n        <li role="example_3" class="important"> By class: we could search for every tag with a given class </li>\n        <li> and so on... </li>\n    </ol>\n    <div>\n        <p>Div tags are used to group block-elements and structure the web page.</p>\n    </div>\n\n    <br>\n    <br>\n\n\n    <h3 style="color: green">Exercises:</h5>\n    <div class="exercise">\n        <p id="exercise1">Find the text of the first paragraph inside this div.</p>\n    </div>\n    <div class="exercise" id="exercise2">\n        <p>Count the number of <code>&lt;div&gt;</code> elements with the class "exercise".</p>\n    </div>\n    <div class="exercise" id="exercise3">\n        <ul>\n            <li><a href="https://example.com/page1">Page 1</a></li>\n            <li><a href="https://example.com/page2">Page 2</a></li>\n            <li><a href="https://example.com/page3">Page 3</a></li>\n        </ul>\n        <p>Extract all the URLs from the links in this list.</p>\n    </div>\n\n\n</body>\n</html>\n'

# %% [markdown]
# We can then make a traversable `soup` object using the response and search as we did before.

# %%
soup = BeautifulSoup(req.text, 'html.parser') # Instead of using the sample HTML, we're using the HTML from the web that we fetched in the previous step
soup.find_all('li') # Finding all the list elements in the HTML
# Out:
# [<li role="example_1"> By tag: we could search for every li </li>,
#  <li role="example_2"> By id: we could search for the p tag with id="searching_description" </li>,
#  <li class="important" role="example_3"> By class: we could search for every tag with a given class </li>,
#  <li> and so on... </li>,
#  <li><a href="https://example.com/page1">Page 1</a></li>,
#  <li><a href="https://example.com/page2">Page 2</a></li>,
#  <li><a href="https://example.com/page3">Page 3</a></li>]

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    BeautifulSoup
#   </h1>
#   <p>
#    BeautifulSoup is a Python library for parsing HTML documents. We can use it to extract data from HTML we fetch
#         from the web.
#         Here, we're just using it to parse some simple sample HTML.
#   </p>
#   <h2 class="important">
#    Searching the tree
#   </h2>
#   <p id="searching_description" style="color: red">
#    BeautifulSoup allows us to search the HTML tree in lots of different ways: by tag, by
#         id, by CSS class, and so on.
#   </p>
#   <ol>
#    <li role="example_1">
#     By tag: we could search for every li
#    </li>
#    <li role="example_2">
#     By id: we could search for the p tag with id="searching_description"
#    </li>
#    <li class="important" role="example_3">
#     By class: we could search for every tag with a given class
#    </li>
#    <li>
#     and so on...
#    </li>
#   </ol>
#   <div>
#    <p>
#     Div tags are used to group block-elements and structure the web page.
#    </p>
#   </div>
#   <br/>
#   <br/>
#   <h3 style="color: green">
#    Exercises:
#    <div class="exercise">
#     <p id="exercise1">
#      Find the text of the first paragraph inside this div.
#     </p>
#    </div>
#    <div class="exercise" id="exercise2">
#     <p>
#      Count the number of
#      <code>
#       &lt;div&gt;
#      </code>
#      elements with the class "exercise".
#     </p>
#    </div>
#    <div class="exercise" id="exercise3">
#     <ul>
#      <li>
#       <a href="https://example.com/page1">
#        Page 1
#       </a>
#      </li>
#      <li>
#       <a href="https://example.com/page2">
#        Page 2
#       </a>
#      </li>
#      <li>
#       <a href="https://example.com/page3">
#        Page 3
#       </a>
#      </li>
#     </ul>
#     <p>
#      Extract all the URLs from the links in this list.
#     </p>
#    </div>
#   </h3>
#  </body>
# </html>

# %% [markdown]
# #### <font color='Green'><strong>Exercises: </strong></font>
#
# **EX 1** Retrieve the text of the paragraph (`<p>`) with the id "exercise1".

# %%
### 1. Add Solution Here ###

exercise1 = soup.find('p', {'id':'exercise1'})

exercise1.get_text()
# Out:
# 'Find the text of the first paragraph inside this div.'

# %% [markdown]
# **EX 2** Count the number of `<div>` elements on the page that have the class "exercise".

# %%
### 2. Add Solution Here ###
exercise_divs = soup.find_all('div', class_='exercise')
print(len(exercise_divs))
# Out:
# 3

# %% [markdown]
# **EX 3** Extract and print all the URLs from the anchor (`<a>`) tags within the list in div with the id "exercise3".

# %%
### 3. Add Solution Here ###

anchor_tags = soup.find_all('a')
for tag in anchor_tags:
    print(tag['href'])
# Out:
# https://example.com/page1
# https://example.com/page2
# https://example.com/page3

# %% [markdown]
# <br>
#
# -----
#
# <br>
#
# # Part 2. A Real Example
#
# ## Scraping Prices from M&S
#
# <div style="display: flex; align-items: flex-start;">
#     <div style="flex: 0 1.75 auto; ">
#         <img src="https://raw.githubusercontent.com/FM-ds/ScrapingWorkshop/main/notebook_images/ms_plants.png" width="500px">
#     </div>
#     <div style="flex: 1 1 auto; margin-top: 10px; margin-right: 150px">
#         Scraping the sample html is a basic introduction. Let's move to collecting some real-world data.
#
# Marks and Spencers is a high-end British supermarket. Let's see if we can collect prices from one of their pages. Josh and I scrape around 100K prices every day to investigate inflation but there are lots of other uses for this data as well:
#
# - **Price Comparisons**: You could make a supermarket vs supermarket price comparison tool
# - **Market Research**: Maybe you want to investigate pricing of your competitors
# - **Procurement**: Waiting for sales to emerge
#
# Today, we'll try scraping prices from just one page, Marks and Spencers' plants: https://www.marksandspencer.com/l/flowers-and-plants/plants?sort=best_seller+desc
#     </div>
# </div>

# %% [markdown]
# <br>
# <br>
#
# ## Identifying Structure with Inspect Element
#
# Before we write any code, we should use inspect element to see how prices, pictures and more are defined in the HTML.
#
# <img src="https://raw.githubusercontent.com/FM-ds/ScrapingWorkshop/main/notebook_images/ms_inspect_element.png" width="800vw">
#
# There are lots of elements and intimidating details but here we can see:
#
# - Product Details are contained in `<div>` elements with a `data-tagg` attribute that starts with `product-card-`
# - Product Titles are found in `<h2>` elements within the `product-card-` divs
#
# We can also see that the `<a>` tag (a link) has the `aria-label` defined. The `aria-label` is part of the ARIA standard (Accessible Rich Internet Applications) which helps make websites more accessible. We can use this description for our own benefit though.

# %% [markdown]
# <br>
# <br>
#
# ## Extracting Product Info
#
# First, we'll download the HTML from the M&S site and then we'll search for all the product cards to find their titles.

# %%
url = "https://www.marksandspencer.com/l/flowers-and-plants/plants?sort=best_seller+desc"
req = requests.get(url) # Making a request for the M&S plants page
soup = BeautifulSoup(req.text, 'html.parser') # Parsing the HTML using BeautifulSoup and the built-in HTML parser

# %% [markdown]
# <br>
#
# ### Product Titles
#
# Let's try and find all the `product-card-` divs and then look for the `<a>` with the aria label in each one.
#
# First we'll build a list of all divs that contain product details by searching for all elements with the data-tagg attribute that contain "product-card".
#
# For each of these product divs, we'll then search for the `<a>` tag with the `aria-label` attribute, the first `<a>` tag in each `product-card-` `div`.

# %%
soup.find_all('div', {'data-tagg': lambda x: x and "product-card" in x})
# Out:
# [<div class="css-1t6g62f exuwcw0" data-tagg="product-card-P60178395" display="flex" id="P60178395"><style data-emotion="css w8rns">.css-w8rns{height:100%;}</style><div class="css-w8rns e1li8zjl2"><style data-emotion="css wtfxn9">.css-wtfxn9{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}.css-wtfxn9 >*+*{margin-top:8px;}</style><div class="css-wtfxn9 e1jwa6pl3"><style data-emotion="css 7vyx9p">.css-7vyx9p{height:100%;position:relative;margin-bottom:4px;}.css-7vyx9p:hover .e1jwa6pl7{-webkit-text-decoration:underline;text-decoration:underline;}.css-7vyx9p:hover .e1jwa6pl6{-webkit-text-decoration:underline;text-decoration:underline;}</style><div class="css-7vyx9p e1jwa6pl5"><style data-emotion="css 14so3a9">.css-14so3a9{-webkit-text-decoration:none;text-decoration:none;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><a aria-label="Product name is Spring Flowering Basket, Price is £30, Product is Free Delivery, Rating is 4.38 out of 5" class="css-14so3a9 e1jwa6pl4" href="/spring-flowering-basket-delivery-from-3rd-january-2024-/p/flp60178395#intid=pid_pg1pip40g2r1c1|prodflag_submsg-Free%20Delivery" tabindex="0"><div class="css-bjn8wh e1jwa6pl2"><style data-emotion="css 1qgq5o7">.css-1qgq5o7{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}@media (hover: none){.css-1qgq5o7:hover button{display:none;}}</style><div class="css-1qgq5o7 e1418iio1" style="aspect-ratio:auto 384 / 500"><style data-emotion="css 1braa85">.css-1braa85{position:relative;-webkit-align-self:flex-end;-ms-flex-item-align:flex-end;align-self:flex-end;-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;}</style><div class="css-1braa85 e1418iio0"><style data-emotion="css 1mfnfgw">.css-1mfnfgw{position:relative;overflow:hidden;}.css-1mfnfgw:hover .eob21oc2{z-index:-1;}.css-1mfnfgw:hover .eob21oc1{left:0;}</style><div class="css-1mfnfgw eob21oc0"><style data-emotion="css kbxr04">.css-kbxr04{position:relative;left:0;}</style><style data-emotion="css q16hrq">.css-q16hrq{max-width:100%;height:100%;vertical-align:bottom;position:relative;left:0;}</style><img alt="Spring Flowering Basket" class="eob21oc2 css-q16hrq e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60178395" decoding="async" fetchpriority="high" height="500" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_0?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_0?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_0?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_0?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_0?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_0?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_0?wid=1024&amp;qlt=80 1024w" style="color:transparent;style:[object Object];background-color:#f5f5f5" width="384"/><style data-emotion="css 1tyhxlc">.css-1tyhxlc{position:absolute;left:100%;}</style><style data-emotion="css o7pb8">.css-o7pb8{max-width:100%;height:100%;vertical-align:bottom;position:absolute;left:100%;}</style><img alt="Spring Flowering Basket" class="eob21oc1 css-o7pb8 e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60178395" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_90?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_ ...
#            to right,
#            rgba(255 255 255 / 0%),
#            rgba(255 255 255) 50%
#          );right:0;width:calc(1.571428 * 0.875rem);top:calc(1.571428 * 0.875rem);height:calc(1.571428 * 0.875rem);}</style><h2 class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">Spring Flowering Basket</h2></a></div><style data-emotion="css 1voysy4">.css-1voysy4{padding:0;background:none;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}</style><button aria-hidden="true" class="css-1voysy4 ecmufep2"><style data-emotion="css 1qkvt8e">.css-1qkvt8e{margin-right:2px;}</style><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">4.4</span><style data-emotion="css f8w7wm">.css-f8w7wm{margin-top:2px;margin-right:0.25rem;}</style><div class="css-f8w7wm ecmufep0"><style data-emotion="css 1qzcx6m">.css-1qzcx6m{color:#000000;line-height:0;position:relative;width:66px;margin:0;}</style><div aria-label="Average rating: 4.38 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css 1qnzqf4">.css-1qnzqf4{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 4.38 + 2.27% * (4.38 - 0.5));}</style><div class="css-1qnzqf4 evt9jvs0"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#000000;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span></div></div></div><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg" style="text-decoration:underline;--typography-gutter-bottom:0rem">976 reviews</span></button><style data-emotion="css qslnu8">.css-qslnu8{margin-top:0.5rem;}</style><p class="media-0_typography__FoTwO media-0_textXs__ZzHWu media-0_text__B7tLg media-0_strong__aXigV css-qslnu8 e1jwa6pl1" style="color:#1e5a7a;--typography-gutter-bottom:0rem">Free Delivery</p></div></div><style data-emotion="css 1usqc3g">.css-1usqc3g{width:100%;margin-top:0.5rem;}</style><button class="style_btn__PyoF9 style_btnSecondary__A_eLp css-1usqc3g e1joqggy0">Add to bag</button><div class="css-1wpci9j en59o9g1" display="flex" style="display:none"><span aria-label="loading" class="render-svg_renderSvg__n5Nsc icon css-1kgy1u9 en59o9g0" role="img" style="--render-svg-icon-color:#000000;--render-svg-icon-url:url('https://static.marksandspencer.com/icons/svgs/Loading.svg?key=v3');--render-svg-height:48px;--render-svg-width:48px;--render-svg-background-size:36px"></span></div></div>,
#  <div class="css-1t6g62f exuwcw0" data-tagg="product-card-P21037669" display="flex" id="P21037669"><div class="css-w8rns e1li8zjl2"><div class="css-wtfxn9 e1jwa6pl3"><div class="css-7vyx9p e1jwa6pl5"><a aria-label="Product name is Oriental Lily, Price is £25, Product is Free Delivery, Rating is 4.64 out of 5" class="css-14so3a9 e1jwa6pl4" href="/oriental-lily/p/flp21037669#intid=pid_pg1pip40g2r1c2|prodflag_submsg-Free%20Delivery" tabindex="0"><div class="css-bjn8wh e1jwa6pl2"><div class="css-1qgq5o7 e1418iio1" style="aspect-ratio:auto 384 / 500"><div class="css-1braa85 e1418iio0"><div class="css-1mfnfgw eob21oc0"><img alt="Oriental Lily" class="eob21oc2 css-q16hrq e1uv1k6x0" data-nimg="1" data-tagg="product-image-P21037669" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_0?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_0?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_0?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_0?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_0?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_0?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_0?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/><img alt="Oriental Lily" class="eob21oc1 css-o7pb8 e1uv1k6x0" data-nimg="1" data-tagg="product-image-P21037669" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_90?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_90?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_90?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_
><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">4.2</span><div class="css-f8w7wm ecmufep0"><div aria-label="Average rating: 4.2 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css vquy0l">.css-vquy0l{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 4.2 + 2.27% * (4.2 - 0 ...
#  <div class="css-1t6g62f exuwcw0" data-tagg="product-card-P60552823" display="flex" id="P60552823"><div class="css-w8rns e1li8zjl2"><div class="css-wtfxn9 e1jwa6pl3"><div class="css-7vyx9p e1jwa6pl5"><a aria-label="Product name is Mum's Jasmine Heart Ceramic Planter, Price is £30, Product is Free Delivery, Rating is 4.47 out of 5" class="css-14so3a9 e1jwa6pl4" href="/mums-jasmine-heart-ceramic/p/flp60552823#intid=pid_pg1pip40g2r2c2|prodflag_submsg-Free%20Delivery" tabindex="0"><div class="css-bjn8wh e1jwa6pl2"><div class="css-1qgq5o7 e1418iio1" style="aspect-ratio:auto 384 / 500"><div class="css-1braa85 e1418iio0"><div class="css-1mfnfgw eob21oc0"><img alt="Mum's Jasmine Heart Ceramic Planter" class="eob21oc2 css-q16hrq e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60552823" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_0?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_0?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_0?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_0?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_0?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_0?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_0?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/><img alt="Mum's Jasmine Heart Ceramic Planter" class="eob21oc1 css-o7pb8 e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60552823" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_90?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_90?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_90?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_90?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_90?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_90?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29234233_NC_X_EC_90?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/></div></div></div></div><div class="css-4c6dm7 e1li8zjl1"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg media-0_strong__aXigV css-17fd1w8 eva4m80" style="--typography-gutter-bottom:0rem">£30</span></div><h2 class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">Mum's Jasmine Heart Ceramic Planter</h2></a></div><button aria-hidden="true" class="css-1voysy4 ecmufep2"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">4.5</span><div class="css-f8w7wm ecmufep0"><div aria-label="Average rating: 4.47 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css 139cfl5">.css-139cfl5{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 4.47 + 2.27% * (4.47 - ...
1uv1k6x0" data-nimg="1" data-tagg="product-image-P60583983" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29302796_NC_X_EC_90?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29302796_NC_X_EC_90?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29302796_NC_X_EC_90?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29302796_NC_X_EC_90?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29302796_NC_X_EC_90?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29302796_NC_X_EC_90?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29302796_NC_X_EC_90?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/></div></div></div><style data-emotion="css 1t27030">.css-1t27030{bottom:0;left:0;z-index:1;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}</style><div class="css-1t27030 e1jwa6pl0"><style data-emotion="css 1oij81p">.css-1oij81p{--background-color:#000000;--text-color:#ffffff;background:var(--background-color);color:var(--text-color);font-size:0.75rem;padding:0.25rem 0.5rem;position:absolute;bottom:0;left:0;}</style><span class="css-1oij81p e8cab3o0">New</span></div></div><div class="css-4c6dm7 e1li8zjl1"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg media-0_strong__aXigV css-17fd1w8 eva4m80" style="--typography-gutter-bottom:0rem">£30</span></div><h2 class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">Emma Bridgewater Bulb Collection</h2></a></div><button aria-hidden="true" class="css-1voysy4 ecmufep2"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B ...
#  <div class="css-1t6g62f exuwcw0" data-tagg="product-card-P60547378" display="flex" id="P60547378"><div class="css-w8rns e1li8zjl2"><div class="css-wtfxn9 e1jwa6pl3"><div class="css-7vyx9p e1jwa6pl5"><a aria-label="Product name is Calla Lily Ceramic - Pink, Price is £25, Product is Free Delivery, Rating is 4.43 out of 5" class="css-14so3a9 e1jwa6pl4" href="/calla-lily-plant-in-ceramic-pot/p/flp60547378#intid=pid_pg1pip40g2r4c1|prodflag_submsg-Free%20Delivery" tabindex="0"><div class="css-bjn8wh e1jwa6pl2"><div class="css-1qgq5o7 e1418iio1" style="aspect-ratio:auto 384 / 500"><div class="css-1braa85 e1418iio0"><div class="css-1mfnfgw eob21oc0"><img alt="Calla Lily Ceramic - Pink" class="eob21oc2 css-q16hrq e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60547378" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_0?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_0?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_0?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_0?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_0?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_0?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_0?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/><img alt="Calla Lily Ceramic - Pink" class="eob21oc1 css-o7pb8 e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60547378" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_90?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_90?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_90?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_90?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_90?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_90?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227624_NC_X_EC_90?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/></div></div></div></div><div class="css-4c6dm7 e1li8zjl1"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg media-0_strong__aXigV css-17fd1w8 eva4m80" style="--typography-gutter-bottom:0rem">£25</span></div><h2 class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">Calla Lily Ceramic - Pink</h2></a></div><button aria-hidden="true" class="css-1voysy4 ecmufep2"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">4.4</span><div class="css-f8w7wm ecmufep0"><div aria-label="Average rating: 4.43 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css 5ign4q">.css-5ign4q{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 4.43 + 2.27% * (4.43 - 0.5));}</style><div class="css-5ign4 ...
="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">White Heart Orchid</h2></a></div><button aria-hidden="true" class="css-1voysy4 ecmufep2"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">4.5</span><div class="css-f8w7wm ecmufep0"><div aria-label="Average rating: 4.53 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css w9y1bo">.css-w9y1bo{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 4.53 + 2.27% * (4.53 - 0.5));}</style><div class="css-w9y1bo evt9jvs0"><span aria-label="" class="re ...
#  <div class="css-1t6g62f exuwcw0" data-tagg="product-card-P60513966" display="flex" id="P60513966"><div class="css-w8rns e1li8zjl2"><div class="css-wtfxn9 e1jwa6pl3"><div class="css-7vyx9p e1jwa6pl5"><a aria-label="Product name is Kalanchoe Gift Bag with Prosecco, Price is £25, Product is Free Delivery, Rating is 4.39 out of 5" class="css-14so3a9 e1jwa6pl4" href="/kalanchoe-gift-bag-with-prosecco/p/flp60513966#intid=pid_pg1pip40g2r6c1|prodflag_submsg-Free%20Delivery" tabindex="0"><div class="css-bjn8wh e1jwa6pl2"><div class="css-1qgq5o7 e1418iio1" style="aspect-ratio:auto 384 / 500"><div class="css-1braa85 e1418iio0"><div class="css-1mfnfgw eob21oc0"><img alt="Kalanchoe Gift Bag with Prosecco" class="eob21oc2 css-q16hrq e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60513966" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_0?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_0?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_0?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_0?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_0?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_0?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_0?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/><img alt="Kalanchoe Gift Bag with Prosecco" class="eob21oc1 css-o7pb8 e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60513966" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_90?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_90?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_90?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_90?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_90?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_90?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29170753_NC_X_EC_90?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/></div></div></div></div><div class="css-4c6dm7 e1li8zjl1"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg media-0_strong__aXigV css-17fd1w8 eva4m80" style="--typography-gutter-bottom:0rem">£25</span></div><h2 class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">Kalanchoe Gift Bag with Prosecco</h2></a></div><button aria-hidden="true" class="css-1voysy4 ecmufep2"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">4.4</span><div class="css-f8w7wm ecmufep0"><div aria-label="Average rating: 4.39 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css 1qnc3ew">.css-1qnc3ew{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 4.39 + 2.27% * (4.39 - 0.5)) ...
# ...
#  <div class="css-1t6g62f exuwcw0" data-tagg="product-card-P60547328" display="flex" id="P60547328"><div class="css-w8rns e1li8zjl2"><div class="css-wtfxn9 e1jwa6pl3"><div class="css-7vyx9p e1jwa6pl5"><a aria-label="Product name is Large Ficus Rubber Plant, Price is £28, Product is Free Delivery, Rating is 4.23 out of 5" class="css-14so3a9 e1jwa6pl4" href="/large-ficus-rubber-plant/p/flp60547328#intid=pid_pg1pip40g2r19c2|prodflag_submsg-Free%20Delivery" tabindex="0"><div class="css-bjn8wh e1jwa6pl2"><div class="css-1qgq5o7 e1418iio1" style="aspect-ratio:auto 384 / 500"><div class="css-1braa85 e1418iio0"><div class="css-1mfnfgw eob21oc0"><img alt="Large Ficus Rubber Plant" class="eob21oc2 css-q16hrq e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60547328" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_0?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_0?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_0?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_0?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_0?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_0?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_0?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/><img alt="Large Ficus Rubber Plant" class="eob21oc1 css-o7pb8 e1uv1k6x0" data-nimg="1" data-tagg="product-image-P60547328" decoding="async" height="500" loading="lazy" sizes="(min-width: 768px) 20vw, 30vw" src="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_90?wid=1024&amp;qlt=80" srcset="https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_90?wid=128&amp;qlt=80 128w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_90?wid=256&amp;qlt=80 256w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_90?wid=384&amp;qlt=80 384w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_90?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_90?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29227280_NC_X_EC_90?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/></div></div></div></div><div class="css-4c6dm7 e1li8zjl1"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg media-0_strong__aXigV css-17fd1w8 eva4m80" style="--typography-gutter-bottom:0rem">£28</span></div><h2 class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">Large Ficus Rubber Plant</h2></a></div><button aria-hidden="true" class="css-1voysy4 ecmufep2"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">4.2</span><div class="css-f8w7wm ecmufep0"><div aria-label="Average rating: 4.23 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css aowwan">.css-aowwan{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 4.23 + 2.27% * (4.23 - 0.5));}</style><div class="css-aowwan evt9jvs0 ...
#  <div class="css-1t6g62f exuwcw0" data-tagg="product-card-P60547327" display="flex" id="P60547327"><div class="css-w8rns e1li8zjl2"><div class="css-wtfxn9 e1jwa6pl3"><div class="css-7vyx9p e1jwa6pl5"><a aria-label="Product name is Extra Large Dracaena Plant with Woven Basket, Price is £60, Product is Free Delivery, Rating is 4.75 out of 5" class="css-14so3a9 e1jwa6pl4" href="/extra-large-dracaena-plant-with-woven-basket/p/flp60547327#intid=pid_pg1pip40g2r20c1|prodflag_submsg-Free%20Delivery" tabindex="0"><div class="css-bjn8wh e1jwa6pl2"><div class="css-1qgq5o7 e1418iio1" style="aspect-ratio:auto 384 / 500"><div class="css-1braa85 e1418iio0"><div class="css-1mfnfgw eob21oc0"><img alt="Extra Large Dracaena Plant with Woven Basket" class="eob21oc2 css-q16hrq e1uv1k6x0" data-nimg="1" data-tagg="product-image-P
, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29126439_NC_X_EC_90?wid=640&amp;qlt=80 640w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29126439_NC_X_EC_90?wid=768&amp;qlt=80 768w, https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_29126439_NC_X_EC_90?wid=1024&amp;qlt=80 1024w" style="color:transparent;background-color:#f5f5f5" width="384"/></div></div></div></div><div class="css-4c6dm7 e1li8zjl1"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg media-0_strong__aXigV css-17fd1w8 eva4m80" style="--typography-gutter-bottom:0rem">£25</span></div><h2 class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-3tvoqx e1jwa6pl6" style="--typography-gutter-bottom:0rem">Ficus Robusta Plant With Ceramic Pot</h2></a></div><button aria-hidden="true" class="css-1voysy4 ecmufep2"><span class="media-0_typography__FoTwO media-0_textSm__Q52Mz media-0_text__B7tLg css-1qkvt8e ecmufep1" style="--typography-gutter-bottom:0rem">3.9</span><div class="css-f8w7wm ecmufep0"><div aria-label="Average rating: 3.92 out of 5" class="css-1qzcx6m evt9jvs1" role="img"><span aria-label="" class="render-svg_renderSvg__n5Nsc render-svg_canBeColoured__ArUTs" role="presentation" style="--render-svg-icon-color:#cccccc;--render-svg-icon-url:url('https://static.marksandspencer.com/images/star-rating-icon.svg?key=v3');--render-svg-height:16px;--render-svg-width:66px;--render-svg-background-size:contain"></span><style data-emotion="css 1gmjdq5">.css-1gmjdq5{height:100%;overflow:hidden;position:absolute;top:0;width:calc(18.18% * 3.92 +  ...

# %%
# find all divs with data-tagg attribute that contain "product-card" and potentially other values
product_divs = soup.find_all('div', attrs={'data-tagg': lambda x: x and "product-card" in x}) # Using a lambda function to find all divs with data-tagg attribute that contain "product-card" and potentially other values
for product_div in product_divs: # Looping through the first 10 product divs
    a_tag = product_div.find('a') # Finding the first a tag in the product div
    # get the aria-label attribute of the a tag
    aria_label = a_tag['aria-label'] # Getting the value of the aria-label attribute of the a tag
    print(aria_label) # Printing the value of the aria-label attribute of the a tag
# Out:
# Product name is Spring Flowering Basket, Price is £30, Product is Free Delivery, Rating is 4.38 out of 5
# Product name is Oriental Lily, Price is £25, Product is Free Delivery, Rating is 4.64 out of 5
# Product name is Yellow Rose Plant with Ceramic Pot, Price is £20, Product is Free Delivery, Rating is 4.2 out of 5
# Product name is Mum's Jasmine Heart Ceramic Planter, Price is £30, Product is Free Delivery, Rating is 4.47 out of 5
# Product name is Amethyst Heart Orchid, Price is £30, Product is Free Delivery, Rating is 4.46 out of 5
# Product name is Emma Bridgewater Bulb Collection, Price is £30, Product is Free Delivery, Rating is 4.44 out of 5
# Product name is Calla Lily Ceramic - Pink, Price is £25, Product is Free Delivery, Rating is 4.43 out of 5
# Product name is White Miniature Phalaenopsis Orchid in Ceramic Pot, Price is £20, Product is Free Delivery, Rating is 4.71 out of 5
# Product name is Large Flowering Basket, Price is £40, Product is Free Delivery, Rating is 4.16 out of 5
# Product name is White Heart Orchid, Price is £30, Product is Free Delivery, Rating is 4.53 out of 5
# Product name is Kalanchoe Gift Bag with Prosecco, Price is £25, Product is Free Delivery, Rating is 4.39 out of 5
# Product name is Large Peace Lily in Basket, Price is £30, Product is Free Delivery, Rating is 4.68 out of 5
# Product name is Pink Miniature Phalaenopsis Orchid in Ceramic Pot, Price is £20, Product is Free Delivery, Rating is 4.74 out of 5
    for part in parts:
        if "Product name is " in part:
            product_details['name'] = part.replace("Product name is ", "")
        elif "Price is £" in part:
            product_details['price'] = part.replace("Price is £", "")
        elif "Rating is " in part:
            product_details['rating'] = part.replace("Rating is ", "").replace(" out of 5", "") # keeping just the rating itself
        elif "Product is " in part: # captures stuff like Free delivery
            product_details['details'] = part.replace("Product is ", "")
    return product_details # Returning the product details dictionary

test_details = "Product name is Oriental Lily, Price is £25, Product is Free Delivery, Rating is 4.64 out of 5"
product_details_from_label(test_details) # Testing the function with a sample label
# Out:
# {'name': 'Oriental Lily',
#  'price': ' 25',
#  'details': ' Free Delivery',
#  'rating': ' 4.64'}

# %% [markdown]
# We can now use our function `product_details_from_label` to go from the accesibility labels ("Product name is...") to structured product information.

# %%
products = [] # Creating an empty list to store the product details

# find all divs with data-tagg attribute that contain "product-card" and potentially other values
product_divs = soup.find_all('div', attrs={'data-tagg': lambda x: x and "product-card" in x}) # Using a lambda function to find all divs with data-tagg attribute that contain "product-card" and potentially other values
for product_div in product_divs: # Looping through the first 10 product divs
    a_tag = product_div.find('a') # Finding the first a tag in the product div
    aria_label = a_tag['aria-label'] # Getting the value of the aria-label attribute of the a tag

    product_details = product_details_from_label(aria_label) # Using the function to get the product details from the aria-label
    products.append(product_details) # Appending the product details to the list of products

products[:5] # let's take a peek at the first 5 products
# Out:
# [{'name': 'Spring Flowering Basket',
#   'price': ' 30',
#   'details': ' Free Delivery',
#   'rating': ' 4.38'},
#  {'name': 'Oriental Lily',
#   'price': ' 25',
#   'details': ' Free Delivery',
#   'rating': ' 4.64'},
#  {'name': 'Yellow Rose Plant with Ceramic Pot',
#   'price': ' 20',
#   'details': ' Free Delivery',
#   'rating': ' 4.2'},
#  {'name': "Mum's Jasmine Heart Ceramic Planter",
#   'price': ' 30',
#   'details': ' Free Delivery',
#   'rating': ' 4.47'},
#  {'name': 'Amethyst Heart Orchid',
#   'price': ' 30',
#   'details': ' Free Delivery',
#   'rating': ' 4.46'}]

# %% [markdown]
# <br>
# <br>
#
# ## Finding more product information: rank, image and link
#
# This is a good start but we probably want more information about each product than just names, prices and ratings.
#
# One useful bit of information is just the products rank on the page (products are sorted by `best sellers`). Thankfully this is easy, the `divs` position in `product_divs` is its rank.
#
# We also want to get the urls of images and the product pages.
#
# ### Images
# Images are easy to find. We'll just look for `img` tags within the `divs`.
#
# <img src="https://raw.githubusercontent.com/FM-ds/ScrapingWorkshop/main/notebook_images/ms_inspect_image.png" width="600">
#
#
# ### Links
# The links are also easy. We can just look at the `href` attribute of the `a` tag.

# %%
products = [] # Creating an empty list to store the product details

# find all divs with data-tagg attribute that contain "product-card" and potentially other values
product_divs = soup.find_all('div', attrs={'data-tagg': lambda x: x and "product-card" in x}) # Using a lambda function to find all divs with data-tagg attribute that contain "product-card" and potentially other values
for i, product_div in enumerate(product_divs): # Looping through the first 10 product divs
    a_tag = product_div.find('a') # Finding the first a tag in the product div
    aria_label = a_tag['aria-label'] # Getting the value of the aria-label attribute of the a tag

    # extract names, prices, details and ratings from the aria-label
    product_details = product_details_from_label(aria_label) # Using the function to get the product details from the aria-label

    # extract the product link from the a tag
    product_details['url'] = a_tag['href'] # Getting the value of the href attribute of the a tag
    product_details['url'] = "http://www.marksandspencer.com" + product_details['url'] # Adding the base URL to the product URL


    # extract the image link from the a tag
    img_tags = a_tag.find_all('img') # Finding the first img tag in the a tag
    product_details['image'] = img_tags[-1]['src'] # Getting the value of the src attribute of the img tag

    # add the rank of the product
    product_details['rank'] = i + 1 # Adding the rank of the product

    products.append(product_details) # Appending the product details to the list of products


products[:2] # let's take a peek at the first 2 products
# Out:
# [{'name': 'Spring Flowering Basket',
#   'price': ' 30',
#   'details': ' Free Delivery',
#   'rating': ' 4.38',
#   'url': 'http://www.marksandspencer.com/spring-flowering-basket-delivery-from-3rd-january-2024-/p/flp60178395#intid=pid_pg1pip40g2r1c1|prodflag_submsg-Free%20Delivery',
#   'image': 'https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00172851_NC_X_EC_90?wid=1024&qlt=80',
#   'rank': 1},
#  {'name': 'Oriental Lily',
#   'price': ' 25',
#   'details': ' Free Delivery',
#   'rating': ' 4.64',
#   'url': 'http://www.marksandspencer.com/oriental-lily/p/flp21037669#intid=pid_pg1pip40g2r1c2|prodflag_submsg-Free%20Delivery',
#   'image': 'https://asset1.cxnmarksandspencer.com/is/image/mands/SD_FD_F44A_00557771_NC_X_EC_90?wid=1024&qlt=80',
#   'rank': 2}]

# %%
len(products)
# Out:
# 40

# %% [markdown]
# # Saving and Visualising
#
# We now have structured product information in `products`, a list of dicts. Let's bring them into a `pandas` dataframe and start to clean the data ready for visualisation.
#
# The only things we have to do are make our `price`, `rating` and `rank` columns numbers.

# %%
df = pd.DataFrame(products) # Creating a DataFrame from the list of products

# make the numeric columns actually numeric
df['price'] = pd.to_numeric(df['price'])
df['rating'] = pd.to_numeric(df['rating'])
df['rank'] = pd.to_numeric(df['rank'])

df = df.dropna(subset=['price', 'rating']) # Dropping rows with missing values in the price and rating columns

df.head() # let's take a peek at the first 5 products
# Out:
#                                   name  price         details  rating  \
# 0              Spring Flowering Basket     30   Free Delivery    4.38
# 1                        Oriental Lily     25   Free Delivery    4.64
# 2   Yellow Rose Plant with Ceramic Pot     20   Free Delivery    4.20
# 3  Mum's Jasmine Heart Ceramic Planter     30   Free Delivery    4.47
# 4                Amethyst Heart Orchid     30   Free Delivery    4.46
#
#                                                  url  \
# 0  http://www.marksandspencer.com/spring-flowerin...
# 1  http://www.marksandspencer.com/oriental-lily/p...
# 2  http://www.marksandspencer.com/yellow-rose-pla...
# 3  http://www.marksandspencer.com/mums-jasmine-he...
# 4  http://www.marksandspencer.com/amethyst-heart-...
#
#                                                image  rank
# 0  https://asset1.cxnmarksandspencer.com/is/image...     1
# 1  https://asset1.cxnmarksandspencer.com/is/image...     2
# 2  https://asset1.cxnmarksandspencer.com/is/image...     3
# 3  https://asset1.cxnmarksandspencer.com/is/image...     4
# 4  https://asset1.cxnmarksandspencer.com/is/image...     5

# %% [markdown]
# Let's start to take a look at our data.
#
# Let's try some simple scatters with plotnine.
#
# First, are higher rated products better selling (rank)?

# %%
# let's plot the price and rating of the products with plotnine
(ggplot(df, aes(x='rating', y='rank')) # Creating a plot with price on the x-axis and rating on the y-axis
 + geom_point() # Adding points to the plot
    + stat_smooth() 
         # Adding a smoothed line to the plot
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Visually there's little evidence for it.
#
# Let's also try looking at the relationship between price and rank - are more expensive products worse selling?
#
# We can do this with plotnine, but let's try making an interactive chart with another module `altair`:

# %%
chart = alt.Chart(df).mark_image(width=45, height=45, opacity=0.7).encode(
    x='rank:Q',
    y='price:Q',
    url='image',
    tooltip=[
        'name', 'price', 'rating'
        ]
) # Creating an interactive scatter plot of the products using Altair

# some extra formatting, you can ignore, change or remove this
chart = chart.properties(
    background='rgb(239,239,239)',
    width=600,
    height=400,
    title=alt.TitleParams(
        "M&S Plants",
        fontSize = 22,
        subtitleFontSize=14,
        subtitle="Price vs Best-Seller Rank",
        subtitleFont="Times New Roman",
        font="Times New Roman",
        fontWeight="normal",
        color="rgb(43, 86, 24)",
        subtitleColor="black",
        anchor="start"
    )
).configure_axis(grid=False).configure_axisY(labelExpr="'£'+datum.value").interactive() #  # Adding some formatting to the chart

chart.display()
# Out:
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
# alt.Chart(...)

# %% [markdown]
# Here, we see that the most expensive products (>£40) are usually among the worst selling products but that this possible relationship doesn't hold across the sample.

# %% [markdown]
# # Where from here?
#
# Today, we've scraped the products from one page of products from a retailer website. IF you want to continue this project or expand your skills, here are some options:
#
# 1. **Scraping Other Pages**: Turn the scraping code above into a method and call it with the URLs of other results.
# 2. **Scraping the whole site**: As an advanced extension, also try automating the building of this list by scraping the page menu bar. Then scrape every category.
# 3. **Collect and compare prices**: Run this code on a few dates, see how prices change. Flower prices might be elevated in the UK with Mothers' day in a few days - do they fall after?

# %% [markdown]
# <br>
#
# -----
#
# <br>

# %% [markdown]
# <hl>
#
# # Extension: Scraping More
#
# At present, we're scraping one page for ~46 products.
#
# This is a good start but it'd be more useful to have a tool that can scrape all the products in a page - or even the whole category or website.
#
# ## A Method to Scrape a Page
#
# Above, to scrape a page, we:
#
# 1. Find all the product divs
# 2. Find the accesibility labels
# 3. Extract product information from accesibility labels
#
# Let's move this all to a function
#
# #### Task: Complete scrape_one_page
#
# Look at the code earlier on ('Finding more product information') and incorporate it into the function below in order to scrape one page. See the `TODO` labels for guidance.

# %%
def scrape_one_page(url):
    """
    (str) -> pd.DataFrame
    Given a URL for a page of products, scrape the product details and return a DataFrame
    """
    req = requests.get(url) # Making a request for the M&S plants page

    # TODO: Make a soup object from the request text
    soup = 

    products = [] # Creating an empty list to store the product details
    product_divs = soup.find_all('div', attrs={'data-tagg': lambda x: x and "product-card" in x}) # Using a lambda function to find all divs with data-tagg attribute that contain "product-card" and potentially other values
    for i, product_div in enumerate(product_divs): # Looping through the first 10 product divs
        a_tag =  # TODO: Find the first a tag in the product div
        aria_label = #TODO: Get the value of the aria-label attribute of the a tag

        product_details = # TODO: use the product_details_from_label function we defined earlier to get the product details from the aria-label

        # extract the product link from the a tag
        product_details['url'] = a_tag['href'] # Getting the value of the href attribute of the a tag
        product_details['url'] = "http://www.marksandspencer.com" + product_details['url'] # Adding the base URL to the product URL

        # extract the image link from the a tag
        img_tags = a_tag.find_all('img') # Finding the first img tag in the a tag
        product_details['image'] = img_tags[-1]['src'] # Getting the value of the src attribute of the img tag

        # add the rank of the product
        product_details['rank'] = i + 1 # Adding the rank of the product

        products.append(product_details) # Appending the product details to the list of products

    return pd.DataFrame(products) # Creating a DataFrame from the list of products

# %% [markdown]
# Let's try the function out on another page:

# %%
url = "https://www.marksandspencer.com/l/gifts/food-and-drink-gifts?sort=best_seller+desc&page=10"
page_products = scrape_one_page(url) # Using the function to scrape the first page of products
page_products.head() # let's take a peek at the first 5 products

# %% [markdown]
# #### Task: Scraping a Whole Category
#
# It would be good to not have to specify every page `url`. Let's write a function where we can specify just a category and then scrape it.

# %%
def scrape_category(category_route):
    """
    (str) -> pd.DataFrame
    Given a category route, scrape all the products from all the pages and return a DataFrame
    """
    page_number = 1 # Starting at page 1

    # Scrape the first page of products
    url = f"{category_route}?page={page_number}&sort=best_seller+desc" # Creating the URL for the current page
    products_df = scrape_one_page(url) # Using the function to scrape the current page of products
    unique_product_count = len(products_df.drop_duplicates(subset=['name'])) # Counting the number of unique products - we'll stop scraping when we're not collecting any more unique products

    while True: # Looping forever until we're not collecting any more products
        url = f"{category_route}?page={page_number}&sort=best_seller+desc" # Creating the URL for the current page
        page_products = scrape_one_page(url) # Using the function to scrape the current page of products

        # merge the new products with the old ones
        products_df = pd.concat([products_df, page_products])

        # if the number of unique products has not changed, we're done
        if len(products_df.drop_duplicates(subset=['name'])) == unique_product_count: 
            break
        
        page_number += 1 # Incrementing the page number
        time.sleep(1)
    return products_df # Concatenating the list of products into a single DataFrame

# %%
category_route = "http://www.marksandspencer.com/l/gifts/food-and-drink-gifts"
food_and_drink_gifts = scrape_category(category_route) # Using the function to scrape the category

# %% [markdown]
# <br>
#
# -----
#
# <br>
#
# ## Advanced Extension Task: Identifying Categories to Scrape
#
# What is we didn't even have to identify the categories ourselves?
#
# The M&S website has a list of brands in its navigation bar. Can we extract these categories?
#
# <img src="https://raw.githubusercontent.com/FM-ds/ScrapingWorkshop/main/notebook_images/brands.png" width="600">
#
# Let's find every link on the page that starts with https://www.marksandspencer.com/l/brands

# %%
soup = BeautifulSoup(requests.get("https://www.marksandspencer.com").text, 'html.parser') # Parsing the HTML using BeautifulSoup and the built-in HTML parser
links = soup.find_all('a') # Finding all the links on the page
links[:5]

# %%
# find only the links with the form https://www.marksandspencer.com/l/brands
brand__links = [link['href'] for link in links if link['href'].startswith("https://www.marksandspencer.com/l/brands")] # Finding only the links with the form https://www.marksandspencer.com/l/brands
brand__links[:5]

# %% [markdown]
# and now let's scrape them!

# %%
all_products_dfs = []

for brand_url in brand__links[:5]: # Looping through the first 5 brand URLs
    print(brand_url) # Printing each brand URL

    # scrape the category
    category_df = scrape_category(brand_url) # Using the function to scrape the category
    category_df['category'] = brand_url.replace("https://www.marksandspencer.com/l/brands/", "").split("#")[0]

    all_products_dfs.append(category_df) # Appending the category DataFrame to the list of all category DataFrames
    all_products_df = pd.concat(all_products_dfs) # Concatenating the list of category DataFrames into a single DataFrame

    time.sleep(1) # Sleeping for 1 second
